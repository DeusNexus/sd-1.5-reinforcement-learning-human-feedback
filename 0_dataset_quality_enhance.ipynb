# %% [markdown]
# # Dataset Quality Pipeline
#
# Thin notebook wrapper around the modular dataset_quality pipeline.

# %%
import sys
from pathlib import Path

root = Path.cwd()
if not (root / "dataset_quality").exists():
    root = root.parent
sys.path.insert(0, str(root))

# %%
from pathlib import Path
import importlib
import dataset_quality.pipeline as dq
importlib.reload(dq)
run_pipeline = dq.run_pipeline

dataset_root = root / "datasets/appa-real-dataset_v2"
output_root = root / "datasets/appa-real-dataset_v2_improved"

run_pipeline(
    dataset_root=dataset_root,
    output_root=output_root,
)
# Out:
# BRISQUE model assets missing; falling back.
#   0%|          | 0/7591 [00:00<?, ?it/s]BRISQUE model assets missing; falling back.
# Downloading: "https://github.com/photosynthesis-team/piq/releases/download/v0.4.0/brisque_svm_weights.pt" to /home/fox/Desktop/Projects/Amrita RLHF/Diffusion_RL_Abi/.torch_cache/checkpoints/brisque_svm_weights.pt
# 100%|██████████| 112k/112k [00:00<00:00, 186kB/s]
# 100%|██████████| 7591/7591 [21:15<00:00,  5.95it/s]
#       imageId  split  age  gender  ethnicity        emotion  \
# 0           0  train    4    male  caucasian        neutral
# 1           1  train   18  female  caucasian        neutral
# 2           2  train   80  female  caucasian  slightlyhappy
# 3           3  train   50  female  caucasian          happy
# 4           4  train   17  female  caucasian  slightlyhappy
# ...       ...    ...  ...     ...        ...            ...
# 7586     7608   test   14    male  caucasian  slightlyhappy
# ...
