# %% [markdown]
# # Dataset Quality Pipeline
#
# Thin notebook wrapper around the modular dataset_quality pipeline.

# %%
import sys
from pathlib import Path

root = Path.cwd()
if not (root / "dataset_quality").exists():
    root = root.parent
sys.path.insert(0, str(root))

# %%
from pathlib import Path
import importlib
import dataset_quality.pipeline as dq
importlib.reload(dq)
run_pipeline = dq.run_pipeline

dataset_root = root / "datasets/appa-real-dataset_v2"
output_root = root / "datasets/appa-real-dataset_v2_improved"

run_pipeline(
    dataset_root=dataset_root,
    output_root=output_root,
)
# Out:
# BRISQUE model assets missing; falling back.
#   0%|          | 0/7525 [00:00<?, ?it/s]BRISQUE model assets missing; falling back.
# 100%|██████████| 7525/7525 [12:18<00:00, 10.18it/s]
#       imageId  split  age  gender  ethnicity        emotion  \
# 0           1  train    5    male  caucasian        neutral
# 1           2  train   20  female  caucasian        neutral
# 2           3  train   76  female  caucasian  slightlyhappy
# 3           4  train   55  female  caucasian          happy
# 4           5  train   17  female  caucasian  slightlyhappy
# ...       ...    ...  ...     ...        ...            ...
# 7520     1974   test   16    male  caucasian  slightlyhappy
# 7521     1975   test   42    male  caucasian          other
# 7522     1976   test   29  female  caucasian  slightlyhappy
# 7523     1977   test   29  female  caucasian  slightlyhappy
# 7524     1978   test   41    male  caucasian          other
#
#                                              image_path  load_error  \
# 0     /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 1     /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 2     /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 3     /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 4     /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# ...                                                 ...         ...
# 7520  /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 7521  /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 7522  /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 7523  /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
# 7524  /home/fox/Desktop/Projects/Amrita RLHF/Diffusi...       False
#
#          lap_var  tenengrad  ...       niqe    brisque  black_bar_score  \
# 0      36.946972  40.324715  ...  10.701824  70.149902              0.0
# 1     163.413513  45.002270  ...   6.703904  33.682251              0.0
# 2      57.585300  41.897190  ...   9.714416  68.729675              0.0
# 3     235.015686  44.614067  ...   6.140495  39.851990              0.0
# 4      77.063210  52.265106  ...   8.753765  66.274414              0.0
# ...          ...        ...  ...        ...        ...              ...
# 7520   51.780060  37.478043  ...   8.884679  68.236206              0.0
# 7521   25.228304  45.396004  ...   9.966146  71.643005              0.0
# 7522   30.867506  43.153881  ...  10.746490  74.152588              0.0
# 7523   57.486221  32.815220  ...   7.350962  48.209778              0.0
# 7524   17.244125  31.584946  ...   8.875917  59.579773              0.0
#
#       black_bar_area_ratio  black_bar_span_ratio  black_bar_solid  \
# 0                      0.0                   0.0            False
# 1                      0.0                   0.0            False
# 2                      0.0                   0.0            False
# 3                      0.0                   0.0            False
# 4                      0.0                   0.0            False
# ...                    ...                   ...              ...
# 7520                   0.0                   0.0            False
# 7521                   0.0                   0.0            False
# 7522                   0.0                   0.0            False
# 7523                   0.0                   0.0            False
# 7524                   0.0                   0.0            False
#
#       black_bar_count     drop_reasons   keep  drop_reasons_str
# 0                   0           [niqe]  False              niqe
# 1                   0               []   True
# 2                   0               []   True
# 3                   0               []   True
# 4                   0               []   True
# ...               ...              ...    ...               ...
# 7520                0               []   True
# 7521                0               []   True
# 7522                0  [niqe, brisque]  False      niqe;brisque
# 7523                0               []   True
# 7524                0               []   True
#
# [7525 rows x 26 columns]
